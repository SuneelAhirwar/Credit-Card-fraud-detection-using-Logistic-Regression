# %% [markdown]
# ### We will load the dependencies for model building

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# ##### after loading the dependencies we will use the dataset.

# %%
#load the credit card datasets
card_data = pd.read_csv('creditcard.csv')

# %%
#head method used for  displaying the first five records
card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
card_data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
# Now we will get the some information about the data
card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
## Check the number of missing values in every columns
card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# Now we will classify the class that which class has more values
card_data['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
#separating the data for analysis
legit = card_data[card_data.Class ==0]
fraud = card_data[card_data.Class==1]

# %% [markdown]
# ## 0 --> Normal Transaction
# ## 1 --> Fraudlent  Transaction

# %%
print(legit.shape)
# Out:
# (284315, 31)

# %%
print(fraud.shape)
# Out:
# (492, 31)

# %%
card_data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
## Compare the values for both transaction
card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
# we will use sample data of normal transactions
legit_sample = legit.sample(n=492)

# %%
## Cancating the  legit sample and fraud transactions
new_data = pd.concat([legit_sample,fraud],axis=0)

# %%
new_data.head()
#new_data.tail()
# Out:
#             Time         V1        V2        V3        V4        V5        V6  \
# 106721   70095.0  -0.026196  0.952639  0.735201  1.473870 -0.664083  0.612093
# 96828    65955.0   1.374319 -1.525487  1.161935 -1.057963 -2.315156 -0.388915
# 182057  125242.0   2.071939  0.263313 -1.746340  0.493333  0.285409 -1.427454
# 122839   76705.0  -1.494935 -0.493538  1.438338 -0.503149 -0.618628  0.724945
# 282457  170912.0 -11.155811  8.912261 -8.627704 -1.010537 -5.743679 -2.435046
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 106721  0.236435 -1.731096 -0.876610  ...  1.573929 -0.293636 -0.152221
# 96828  -1.618460  0.101411 -0.799187  ... -0.236498 -0.275262  0.049394
# 182057  0.311849 -0.422462  0.505457  ...  0.191982  0.767287 -0.044543
# 122839  1.714003  0.154296 -0.743973  ...  0.220028 -0.205638  0.831827
# 282457 -4.896360  6.764624  2.168188  ...  0.310527  0.567455  0.980786
#
# ...

# %%
new_data.shape
# Out:
# (984, 31)

# %%
new_data['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
new_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      92252.739837 -0.008733  0.104285  0.117407  0.040684  0.055689
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.027571  0.030737  0.062712 -0.013262  ... -0.001997 -0.002381
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000851 -0.005542  0.011694 -0.020907  0.024512  0.004433  0.029472
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       74.419411
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
new_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      92252.739837 -0.008733  0.104285  0.117407  0.040684  0.055689
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.027571  0.030737  0.062712 -0.013262  ... -0.001997 -0.002381
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000851 -0.005542  0.011694 -0.020907  0.024512  0.004433  0.029472
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       74.419411
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# #### Now we will split the data into independent and dependent features

# %%
X = new_data.drop(columns='Class', axis=1)
Y = new_data['Class']

# %%
print(X)
# Out:
#             Time         V1        V2        V3        V4        V5        V6  \
# 106721   70095.0  -0.026196  0.952639  0.735201  1.473870 -0.664083  0.612093
# 96828    65955.0   1.374319 -1.525487  1.161935 -1.057963 -2.315156 -0.388915
# 182057  125242.0   2.071939  0.263313 -1.746340  0.493333  0.285409 -1.427454
# 122839   76705.0  -1.494935 -0.493538  1.438338 -0.503149 -0.618628  0.724945
# 282457  170912.0 -11.155811  8.912261 -8.627704 -1.010537 -5.743679 -2.435046
# ...          ...        ...       ...       ...       ...       ...       ...
# 279863  169142.0  -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0   1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0  -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0  -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0   1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
print(Y)
# Out:
# 106721    0
# 96828     0
# 182057    0
# 122839    0
# 282457    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
# Split the data into Training and Testing data
X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.2,stratify=Y, random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %% [markdown]
# #### We will use the Logistic Algorithm for classification model building.

# %%
model = LogisticRegression()

# %%
#Train the logistic regression model with Training data
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
## We will check the accuracy on training data
X_train_prediction = model.predict(X_train)

# %%
training_data_accuracy = accuracy_score(X_train_prediction,Y_train)

# %%
print('Accuracy on training data',training_data_accuracy)
# Out:
# Accuracy on training data 0.9479034307496823

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
test_data_accuracy
# Out:
# 0.9289340101522843

# %%
print('Accuracy on Test data: ', test_data_accuracy)
# Out:
# Accuracy on Test data:  0.9289340101522843
